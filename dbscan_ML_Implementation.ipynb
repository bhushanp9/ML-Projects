# %% [markdown]
# <a href="https://colab.research.google.com/github/bhushanp9/ML-Projects/blob/main/dbscan_ML_Implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x,y = make_moons(n_samples=300,noise=0.05,random_state=82)

# %%
db = DBSCAN(eps=0.2,min_samples=5)
labels = db.fit_predict(x)

# %%
plt.scatter(x[:,0],x[:,1],c=labels,cmap='rainbow')
plt.title("DBSCAN Clustering")
plt.xlabel("x1")
plt.ylabel("x2")
plt.show()

# %%
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_circles
import matplotlib.pyplot as plt

# %%
x,y= make_circles(n_samples=300,factor=0.5,noise=0.05,random_state=82)

# %%
db = DBSCAN(eps=0.1,min_samples=5)
labels = db.fit_predict(x)

# %%
plt.figure(figsize=(6,6))
plt.scatter(x[:,0],x[:,1],c=labels,cmap='rainbow')
plt.title("DBSCAN Clustering of circles")
plt.xlabel("x1")
plt.ylabel("x2")
plt.show()
