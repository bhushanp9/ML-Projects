# %% [markdown]
# <a href="https://colab.research.google.com/github/bhushanp9/ML-Projects/blob/main/SVM_Machine_learning_using_iris_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score

# %%
df = pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
x = df[[ 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
y = df['Species']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state=44)

# %%
svm_model = SVC()

# %%
svm_model.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred = svm_model.predict(x_test)

# %%
print(classification_report(y_test,y_pred)) #y_pred,y_test??
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       0.92      1.00      0.96        12
#  Iris-virginica       1.00      0.92      0.96        13
#
#        accuracy                           0.97        38
#       macro avg       0.97      0.97      0.97        38
#    weighted avg       0.98      0.97      0.97        38

# %%
for i in range(1,101):
  x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state=i)
  svm_model = SVC()
  svm_model.fit(x_train,y_train)
  y_pred = svm_model.predict(x_test)
  print(f'the randome_state is {i} asnd acc is {accuracy_score(y_test,y_pred)}')
# Out:
# the randome_state is 1 asnd acc is 0.9736842105263158
# the randome_state is 2 asnd acc is 0.9736842105263158
# the randome_state is 3 asnd acc is 0.9736842105263158
# the randome_state is 4 asnd acc is 0.9736842105263158
# the randome_state is 5 asnd acc is 0.9736842105263158
# the randome_state is 6 asnd acc is 0.9473684210526315
# the randome_state is 7 asnd acc is 0.868421052631579
# the randome_state is 8 asnd acc is 0.9473684210526315
# the randome_state is 9 asnd acc is 0.9736842105263158
# the randome_state is 10 asnd acc is 1.0
# the randome_state is 11 asnd acc is 0.9210526315789473
# the randome_state is 12 asnd acc is 0.9736842105263158
# the randome_state is 13 asnd acc is 0.9736842105263158
# the randome_state is 14 asnd acc is 0.9736842105263158
# the randome_state is 15 asnd acc is 0.9736842105263158
# the randome_state is 16 asnd acc is 0.9473684210526315
# the randome_state is 17 asnd acc is 0.9736842105263158
# the randome_state is 18 asnd acc is 1.0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

iris = load_iris()
data = sns.load_dataset('iris')  # Load as DataFrame for Seaborn

# Pair plot (shows feature distributions and class separability)
sns.pairplot(data, hue="species", palette="Set1")
plt.suptitle("Pair Plot of Iris Dataset (Colored by Species)", y=1.02)
plt.show()

# %%
from sklearn.svm import SVC
import numpy as np

# Extract 2 features (petal length & width) for simplicity
X = iris.data[:, 2:4]  # Petal length & width
y = iris.target

# Train SVM (linear kernel)
model = SVC(kernel='linear', C=1.0)
model.fit(X, y)

# Create a mesh grid for plotting
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.02),
                     np.arange(y_min, y_max, 0.02))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Plot decision boundaries
plt.contourf(xx, yy, Z, alpha=0.8, cmap=plt.cm.Paired)
plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', cmap=plt.cm.Paired)
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.title('SVM Decision Boundary (Linear Kernel) on Iris Dataset')
plt.show()

# %%
#Why did SMV breakup with logistic regression?
#because SMV needs more space!
